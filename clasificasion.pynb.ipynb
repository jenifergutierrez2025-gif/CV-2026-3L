# %%
import cv2
from ultralytics import YOLO

def hacer_algo(ruta_imagen):
    model = YOLO("yolov8n-cls.pt")
    resultados = model(ruta_imagen)
    resultado = resultados[0]

    id_clase_top1 = resultado.probs.top1
    nombre_categoria = resultado.probs.top1conf.item() * 100

    print(f"prediccion: {nombre_categoria} ({confianza:.2f}%)")

    imagen = cv2.imread(ruta_imagen)
    if imagen is None:
        print("Error: No se pudo cargar la imagen para mostrar el resultado.")
        return

    texto = (f"clase: {nombre_categoria} ({confianza:.2f}%)")
    cv2.putText(imagen, texto, (15, 40) , cv2.FONT_HERSHEY_SIMPLEX,
                0.8, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow("classificacion de imagen", imagen)
    cv2.waitKey(0)
    cv2.destroyAllwindows()       

hacer_algo('kuromi.jpg')
# Out:
# image 1/1 d:\kuromi.jpg: 224x224 frying_pan 0.16, whistle 0.09, microphone 0.08, plate_rack 0.06, cassette 0.05, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 26
#      22     cv2.imshow("classificacion de imagen", imagen)
#      23     cv2.waitKey(0)
#      24     cv2.destroyAllwindows()
#      25
# ---> 26 hacer_algo('kuromi.jpg')
#
# Cell In[10], line 12, in hacer_algo(ruta_imagen)
#       8
#       9     id_clase_top1 = resultado.probs.top1
#      10     nombre_categoria = resultado.probs.top1conf.item() * 100
#      11
# ---> 12     print(f"prediccion: {nombre_categoria} ({confianza:.2f}%)")
#      13
#      14     imagen = cv2.imread(ruta_imagen)
#      15     if imagen is None:
#
# NameError: name 'confianza' is not defined

# %%
pip install opencv-python ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    - -------------------------------------- 2.1/44.0 MB 10.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.1/44.0 MB 31.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.2/44.0 MB 55.4 MB/s eta 0:00:01
#    ---------------------------------------- 44.0/44.0 MB 58.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 51.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 9.3/9.3 MB 78.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 84.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
# ...
